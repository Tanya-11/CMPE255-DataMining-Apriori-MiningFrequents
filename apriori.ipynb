# %%
# Apriori algorithm: Generating frequent itemsets
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from collections import defaultdict

# %%
# load basket dataset
#  transforming the data such that each row is a transaction
basket = pd.read_csv(r"C:\Users\Checkout\Downloads\baskets.csv")

combined = defaultdict(list)
for index, row in basket.iterrows():
    if row['Item'] != 'NONE' :
        combined[(row["Transaction"])].append(row['Item']) #created dictionary where key is transaction number and value is list of items

records = []
for key, val in combined.items():
    records.append(list(set(val))) #created list of lists from the dictionary to get the data in required data structure for further data transformation
display(records)
# Out:
# [['Bread'],
#  ['Scandinavian'],
#  ['Jam', 'Cookies', 'Hot chocolate'],
#  ['Muffin'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Medialuna', 'Muffin', 'Pastry'],
#  ['Medialuna', 'Tea', 'Pastry', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Muffin', 'Bread'],
#  ['Medialuna', 'Scandinavian'],
#  ['Medialuna', 'Bread'],
#  ['Pastry', 'Coffee', 'Tartine', 'Jam', 'Tea'],
#  ['Basket', 'Bread', 'Coffee'],
#  ['Medialuna', 'Bread', 'Pastry'],
#  ['Mineral water', 'Scandinavian'],
#  ['Medialuna', 'Bread', 'Coffee'],
#  ['Hot chocolate'],
#  ['Farm House'],
#  ['Farm House', 'Bread'],
#  ['Medialuna', 'Bread'],
#  ['Medialuna', 'Bread', 'Coffee'],
#  ['Jam'],
#  ['Muffin', 'Scandinavian'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Jam', 'Bread'],
#  ['Bread'],
#  ['Basket'],
#  ['Muffin', 'Scandinavian'],
#  ['Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Muffin', 'Scandinavian'],
#  ['Tea', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Bread'],
#  ['Scandinavian'],
#  ['Tartine', 'Muffin', 'Juice', 'Coffee'],
#  ['Scandinavian'],
#  ['Tea', 'Bread'],
#  ['Fudge', 'Scandinavian'],
#  ['Medialuna', 'Coffee'],
#  ['Medialuna', 'Hot chocolate', 'Coffee'],
#  ['Coffee'],
#  ['Juice', 'Jam', 'Muffin', "Ella's Kitchen Pouches", 'Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread', 'Victorian Sponge'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Frittata', 'Hearty & Seasonal', 'Tea', 'Coffee'],
#  ['Frittata', 'Coffee'],
#  ['Scandinavian'],
#  ['Soup', 'Hot chocolate', 'Tea', 'Victorian Sponge'],
#  ['Tea'],
#  ['Cookies', 'Juice', 'Coffee'],
#  ['Coffee'],
#  ['Pick and Mix Bowls', 'Hearty & Seasonal', 'Smoothies', 'Coffee'],
#  ['Coffee'],
#  ['Cake'],
#  ['Tartine', 'Coffee', 'Tea', 'Mighty Protein'],
#  ['Frittata', 'Hearty & Seasonal', 'Mineral water'],
#  ['Hearty & Seasonal', 'Muffin', 'Mineral water'],
#  ['Scandinavian', 'Coffee', 'Frittata', 'Tea', 'Chicken sand'],
#  ['Tea', 'Bread', 'Victorian Sponge'],
#  ['Fudge'],
#  ['Muffin'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Jam', 'Frittata'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Fudge', 'Muffin', 'Tea', 'Coffee'],
#  ['Frittata', 'Bread', 'Coffee'],
#  ['Cake', 'Coffee'],
#  ['Tartine', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Pastry', 'Coffee'],
#  ['Juice'],
#  ['Bread'],
#  ['Jam', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea'],
#  ['Coffee'],
#  ['Coke', 'Bread'],
#  ['Coffee'],
#  ['Farm House', 'Tea', 'Pastry'],
#  ['Juice', 'Pastry', 'Coffee'],
#  ['Juice', 'Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Medialuna', 'Muffin', 'Coffee'],
#  ['Tea', 'Cake', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Farm House', 'Muffin'],
#  ['Muffin', 'Bread', 'Pastry'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Cake', 'Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cookies', 'My-5 Fruit Shoot', 'Cake', 'Coffee'],
#  ['Cookies', 'Tea', 'Pastry'],
#  ['Muffin', 'Coffee'],
#  ['Farm House'],
#  ['Bread', 'Coffee'],
#  ['Cookies'],
#  ['Jam', 'Juice', 'Coffee'],
#  ['Soup', 'Coffee'],
#  ['Tea'],
#  ['Jam', 'Coffee'],
#  ['Farm House'],
#  ['Tartine', 'Tea', 'Coffee'],
#  ['Cake', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Pick and Mix Bowls', 'Cookies', 'Tea', 'Juice'],
#  ['Soup', 'Hearty & Seasonal'],
#  ['Hearty & Seasonal', 'Farm House', 'Tea'],
#  ['Bread'],
#  ['Soup', 'Tea'],
#  ['Farm House'],
#  ['Soup', 'Hearty & Seasonal', 'Coffee'],
#  ['Hearty & Seasonal', 'Muffin', 'Bread'],
#  ['Cookies', 'Coffee'],
#  ['Bread'],
#  ['Muffin', 'Tea'],
#  ['Tea'],
#  ['Soup', 'Hearty & Seasonal'],
#  ['Focaccia', 'Tea', 'Coffee'],
#  ['Sandwich'],
#  ['Tartine', 'Coffee'],
#  ['Fudge', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Soup', 'Coke'],
#  ['Muffin'],
#  ['Cookies', 'Muffin', 'Tea', 'Coffee'],
#  ['Hearty & Seasonal', 'Coffee', 'Coke', 'Mighty Protein'],
#  ['Sandwich', 'Muffin', 'Tea'],
#  ['Muffin', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Cookies', 'Bread', 'Hot chocolate'],
#  ['Muffin', 'Mineral water'],
#  ['Tea'],
#  ['Muffin'],
#  ['Juice', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Tea'],
#  ['Muffin', 'Coffee'],
#  ['Sandwich', 'Hearty & Seasonal', 'Mineral water', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Mineral water'],
#  ['Coffee'],
#  ['Soup', 'Tea'],
#  ['Bread', 'Coffee'],
#  ['Muffin', 'Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Jam', 'Tea'],
#  ['Tea'],
#  ["Ella's Kitchen Pouches", 'Pastry'],
#  ['Pastry'],
#  ['Farm House', 'Tea'],
#  ['Tea', 'Victorian Sponge'],
#  ['Tea', 'Pastry'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Soup', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Scandinavian'],
#  ['Cookies', 'Bread', 'Cake'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread', 'Scandinavian'],
#  ['Pastry', 'Coffee'],
#  ['Pastry', 'Scandinavian', 'Coffee'],
#  ['Hearty & Seasonal', 'Muffin', 'Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Soup', 'Coffee'],
#  ['Cookies', 'Tartine', 'Coffee'],
#  ['Bread'],
#  ['Tea', 'Bread'],
#  ['Pastry', 'Coffee'],
#  ['Tartine', 'Coffee'],
#  ['Cookies', 'Bread'],
#  ['Sandwich'],
#  ['Tartine'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Scandinavian'],
#  ['Scandinavian'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Soup', 'Coke', 'Coffee'],
#  ['Cake'],
#  ['Soup', 'Sandwich', 'Tea'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Alfajores'],
#  ['Cake'],
#  ['Tea', 'Bread'],
#  ['Soup', 'Bread', 'Tea', 'Coffee'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Sandwich', 'Coffee'],
#  ['Cookies', 'Tea', 'Pastry', 'Bread'],
#  ['Muffin'],
#  ['Scandinavian'],
#  ['Jam', 'Tea'],
#  ['Alfajores', 'Tea', 'Juice'],
#  ['Soup', 'Muffin', 'Cake', 'Coffee'],
#  ['Coffee', 'Cake', 'Hot chocolate'],
#  ['Cookies', 'Cake'],
#  ['Tea', 'Bread'],
#  ['Alfajores', 'Juice', 'Coffee'],
#  ['Soup', 'Tea', 'Coffee'],
#  ['Hot chocolate'],
#  ['Cookies'],
#  ['Medialuna', 'Coffee'],
#  ['Eggs', 'Bread'],
#  ['Scandinavian'],
#  ['Medialuna'],
#  ['Pastry', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Hot chocolate', 'Pastry', 'Coffee'],
#  ['Coke'],
#  ['Jam', 'Coffee'],
#  ['Tea'],
#  ['Bread', 'Pastry'],
#  ['Alfajores', 'Farm House', 'Coffee'],
#  ['Tea', 'Pastry'],
#  ['Bread'],
#  ['Jam', 'Coffee'],
#  ['Tea', 'Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Farm House', 'Coffee'],
#  ['Farm House', 'Pastry'],
#  ['Alfajores', 'Bread', 'Juice'],
#  ['Pastry', 'Coffee'],
#  ['Alfajores', 'Bread'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Cookies'],
#  ['Hearty & Seasonal'],
#  ['Coffee'],
#  ['Jam', 'Tartine', 'Bread'],
#  ['Farm House', 'Scandinavian'],
#  ['Hearty & Seasonal', 'Muffin', 'Scandinavian', 'Coffee'],
#  ['Tartine', 'Coke', 'Coffee', 'Pick and Mix Bowls'],
#  ['Bread'],
#  ['Alfajores', 'Farm House', 'Scandinavian', 'Coffee'],
#  ['Soup', 'Mineral water', 'Juice'],
#  ['Soup', 'Tea'],
#  ['Cookies', 'Soup', 'Tea', 'Juice'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Fudge'],
#  ['Soup', 'Mineral water', 'Juice', 'Coffee'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal', 'Smoothies'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Sandwich', 'Coffee'],
#  ['Cookies', 'Farm House'],
#  ['Soup', 'Tea', 'Juice'],
#  ['Soup'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Tea'],
#  ['Soup', 'Hearty & Seasonal', 'Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Tea'],
#  ['Tea', 'Coffee'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Tea'],
#  ['Soup', 'Tea'],
#  ['Juice'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Alfajores', 'Coffee'],
#  ['Cookies', 'Juice', 'Pick and Mix Bowls', 'Alfajores', 'Mineral water'],
#  ['Alfajores', 'Coffee'],
#  ['Fudge'],
#  ['Juice', 'Mighty Protein'],
#  ['Alfajores', 'Mineral water', 'Coffee'],
#  ['Coffee', 'Mighty Protein'],
#  ['Alfajores'],
#  ['Bread', 'Coffee'],
#  ['Medialuna'],
#  ['Medialuna', 'Bread'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Medialuna'],
#  ['Sandwich', 'Tea', 'Bread'],
#  ['Bread'],
#  ['Jam', 'Farm House', 'Coffee'],
#  ['Focaccia'],
#  ['Bread'],
#  ['Tartine', 'My-5 Fruit Shoot', 'Bread', 'Pastry'],
#  ['Farm House', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Jam', 'Coffee'],
#  ['Farm House'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Tea', 'Coffee'],
#  ['Jam'],
#  ['Medialuna', 'Pastry'],
#  ['Coffee'],
#  ['Tea'],
#  ['Bread'],
#  ['Bread', 'Pastry'],
#  ['Pastry'],
#  ['Farm House'],
#  ['Tea'],
#  ['Alfajores', 'Fudge', 'Brownie', 'Coffee'],
#  ['Cookies', 'Fudge', 'Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Jam', 'Pastry', 'Coffee'],
#  ['Soup', 'Coffee'],
#  ['Soup', 'Hearty & Seasonal', 'Smoothies', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Medialuna', 'Pastry'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Bread'],
#  ['Hearty & Seasonal',
#   'Coffee',
#   'Sandwich',
#   'Pick and Mix Bowls',
#   'Bread',
#   'Focaccia'],
#  ['Coffee'],
#  ['Sandwich', 'Brownie', 'Coffee'],
#  ['Cookies', 'Brownie'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Sandwich', 'Bread', 'Coffee'],
#  ['Hot chocolate', 'Coffee'],
#  ['Tea'],
#  ['Sandwich', 'Brownie', 'Coffee'],
#  ['Farm House', 'Brownie', 'Pastry', 'Focaccia'],
#  ['Cake', 'Focaccia'],
#  ['Soup', 'Hearty & Seasonal', 'Mineral water'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Tea', 'Cake'],
#  ['Soup', 'Coffee'],
#  ['Fudge', 'Bread', 'Focaccia'],
#  ['Alfajores', 'Coffee', 'Hot chocolate'],
#  ['Cake', 'Brownie', 'Pastry'],
#  ['Medialuna', 'Alfajores', 'Dulce de Leche'],
#  ['Alfajores', 'Dulce de Leche'],
#  ['Bread', 'Cake'],
#  ['Cake', 'Coffee'],
#  ['Bread'],
#  ['Sandwich'],
#  ['Medialuna', 'Alfajores', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Alfajores', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Dulce de Leche'],
#  ['Farm House'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Brownie', 'Coffee', 'Juice', "Ella's Kitchen Pouches", 'Alfajores'],
#  ['Alfajores'],
#  ['Brownie', 'Cookies', 'Juice', 'Alfajores', 'Bread'],
#  ['Cookies', 'Cake'],
#  ['Pick and Mix Bowls'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Tea'],
#  ['Coffee'],
#  ['Farm House', 'Focaccia'],
#  ['Dulce de Leche'],
#  ['Cookies', "Ella's Kitchen Pouches", 'My-5 Fruit Shoot', 'Juice'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Jam', 'Tea', 'Bread'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Pastry'],
#  ['Jam', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Medialuna', 'Bread'],
#  ['Jam', 'Bread'],
#  ['Jam', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Farm House', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Pastry'],
#  ['Coffee'],
#  ['Bread'],
#  ['Brownie', 'Pastry'],
#  ['Farm House'],
#  ['Coffee'],
#  ['Honey', 'Tea', 'Cookies', 'Coffee'],
#  ['Tea'],
#  ['Bread'],
#  ['Brownie'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Tea'],
#  ['Tea'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'The BART'],
#  ['Brownie', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Tartine', 'Mineral water', 'Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Brownie', 'Juice'],
#  ['Pastry', 'Coffee', 'Jam', 'Tea', 'Medialuna', 'Alfajores', 'Bread'],
#  ['Bread'],
#  ['Fudge'],
#  ['Pick and Mix Bowls', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Soup', 'Mineral water', 'Scandinavian', 'Coffee'],
#  ['Pick and Mix Bowls', 'Sandwich', 'Mineral water', 'Juice'],
#  ['Bread', 'Pastry'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Hearty & Seasonal', 'Mineral water', 'Bread', 'Coffee'],
#  ['Tartine', 'Sandwich', 'Brownie', 'Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Tartine', 'Alfajores', 'Coffee'],
#  ['Coffee', 'Mighty Protein'],
#  ['Hot chocolate', 'Coffee'],
#  ['Jam', 'Soup', 'Coffee'],
#  ['Brownie', 'Mineral water'],
#  ['Scandinavian', 'Coffee'],
#  ['Scandinavian', 'Coffee'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Hot chocolate', 'Brownie', 'Coffee'],
#  ['Tea', 'Cake'],
#  ['Medialuna'],
#  ['Alfajores', 'Tea', 'Coffee'],
#  ['Alfajores', 'Brownie', 'Juice', 'Coffee'],
#  ['Sandwich', 'Coffee'],
#  ['Soup', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Bread'],
#  ['Cookies', 'Brownie', 'Tea'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie'],
#  ['Cookies', 'Jam', 'Bread'],
#  ['Coffee'],
#  ['Brownie', 'Tea'],
#  ['Medialuna', 'Alfajores', 'Scandinavian'],
#  ['Cookies', 'Alfajores', 'Coffee', 'Hot chocolate'],
#  ['Brownie'],
#  ['Fudge'],
#  ['Brownie', 'Tea'],
#  ['Fudge', 'Dulce de Leche'],
#  ['Pastry', 'Scandinavian', 'Granola', 'Coffee', 'Fudge', 'Bread'],
#  ['Fudge', 'Bread'],
#  ['Medialuna', 'Coffee', 'Hot chocolate'],
#  ['Bread'],
#  ['Medialuna', 'Bread'],
#  ['Medialuna', 'Jam', 'Bread', 'Coffee'],
#  ['Jam', 'Brownie', 'Coffee'],
#  ['Jam', 'Bread', 'Coffee'],
#  ['Scandinavian'],
#  ['Cookies', 'Coffee'],
#  ['Scandinavian', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Jam', 'Brownie', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Hot chocolate'],
#  ['Bread'],
#  ['Medialuna', 'Bread'],
#  ['Hot chocolate', 'Brownie', 'Coffee'],
#  ['Scandinavian'],
#  ['Basket', 'Bread'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Fudge', 'Cake'],
#  ['Hot chocolate', 'Basket', 'Coffee'],
#  ['Scandinavian'],
#  ['Scandinavian'],
#  ['Medialuna', 'Bread', 'Cake', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Brownie', 'Bread'],
#  ['Medialuna', 'Farm House'],
#  ['Medialuna', 'Bread'],
#  ['Brownie', 'Coffee', 'Hot chocolate', 'Smoothies', 'Medialuna'],
#  ['Brownie', 'Coffee', 'Tea', 'Medialuna', 'Bread'],
#  ['Medialuna', 'Cookies'],
#  ['Medialuna', 'Coffee'],
#  ['Fudge', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Coffee'],
#  ['Brownie', 'Bread', 'Pastry'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Brownie', 'My-5 Fruit Shoot', 'Coffee'],
#  ['Fudge', 'Coffee'],
#  ['Coffee'],
#  ['Basket', 'Coffee'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Brownie', 'Coffee'],
#  ['My-5 Fruit Shoot', 'Brownie', 'Scandinavian'],
#  ['Tartine', 'Hot chocolate', 'Brownie', 'Coffee'],
#  ['Brownie', 'Bread', 'Hot chocolate'],
#  ['Jam', 'Fudge'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Hearty & Seasonal', 'Coffee', 'Mighty Protein', 'Cake', 'Tea'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Scandinavian', 'Cake', 'Victorian Sponge'],
#  ['Tea', 'Cake'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Frittata'],
#  ['Brownie', 'My-5 Fruit Shoot', 'Coffee'],
#  ['Fairy Doors', 'Focaccia'],
#  ['Tea', 'Coffee'],
#  ['Pick and Mix Bowls', 'Hearty & Seasonal', 'Brownie', 'Hot chocolate'],
#  ['Frittata', 'Coffee'],
#  ['Brownie', 'Bread'],
#  ['Frittata'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Farm House'],
#  ['Pick and Mix Bowls', 'Jam', 'Soup', 'Brownie'],
#  ['Hearty & Seasonal', 'Tea', 'Coffee'],
#  ['Bread'],
#  ['Frittata', 'Bread'],
#  ['Scandinavian'],
#  ['Tartine', 'Coffee', 'Hot chocolate'],
#  ['Mighty Protein', 'Coffee'],
#  ['Frittata', 'Coffee'],
#  ['Scandinavian'],
#  ['Hearty & Seasonal', 'Mineral water', 'Coffee'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Soup', 'Hearty & Seasonal', 'Bread', 'Coffee'],
#  ['Brownie', 'Tea', 'Cake'],
#  ['Coffee', 'Mighty Protein'],
#  ['Soup', 'Brownie', 'Tea', 'Coffee'],
#  ['Cake'],
#  ['Coffee', 'Cake', 'Hot chocolate'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Coffee'],
#  ['Frittata', 'Brownie', 'Coffee'],
#  ['Brownie', 'Sandwich', 'Frittata', 'Coke', 'Mineral water'],
#  ['Scandinavian', 'Granola'],
#  ['Coke', 'Coffee'],
#  ['Brownie', 'Tea', 'Cake'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Brownie'],
#  ['Cake'],
#  ['Tea'],
#  ['Soup', 'Sandwich', 'Cake', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Soup', 'Brownie', 'Coffee'],
#  ['Fudge'],
#  ['Bread', 'Focaccia'],
#  ['Jam', 'Farm House', 'Bread'],
#  ['Brownie', 'Hot chocolate'],
#  ['Hot chocolate'],
#  ['Brownie', 'Coffee'],
#  ['Medialuna', 'Pastry'],
#  ['Bread'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Mineral water', 'Coffee'],
#  ['Bread', 'Pastry', 'Hot chocolate'],
#  ['Bread'],
#  ['Bread'],
#  ['Jam', 'Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Medialuna', 'Hearty & Seasonal', 'Focaccia', 'Coffee'],
#  ['Jam', 'Farm House', 'Bread', 'Coffee'],
#  ['Farm House'],
#  ['Medialuna', 'Tea', 'Pastry', 'Coffee'],
#  ['Medialuna', 'Pastry', 'Coffee'],
#  ['Farm House', 'Hot chocolate', 'Basket', 'Coffee'],
#  ['Farm House', 'Pastry'],
#  ['My-5 Fruit Shoot', 'Coffee', 'Hot chocolate'],
#  ['Medialuna', 'Muffin', 'Pastry'],
#  ['Farm House'],
#  ['Muffin', 'Pastry', 'Focaccia'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Focaccia'],
#  ['Jam', 'Hot chocolate', 'Pastry', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Tea'],
#  ['Mineral water', 'Coffee', 'Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Jam', 'Coffee'],
#  ['Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread'],
#  ['Muffin', 'Coffee', 'Hot chocolate'],
#  ['Fudge', 'Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Farm House'],
#  ['Muffin', 'Coffee'],
#  ['Focaccia'],
#  ['Tea', 'Bread'],
#  ['Hot chocolate', 'Coffee'],
#  ['Tartine', 'Jam', 'Pick and Mix Bowls', 'Coffee'],
#  ['Jam'],
#  ['Tartine'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Tartine', 'Juice', 'Pick and Mix Bowls', 'Mineral water'],
#  ['Tea', 'Bread', 'Juice'],
#  ['Cake', 'Coffee'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Brownie', 'Cake', 'Coffee'],
#  ['Coffee', 'Focaccia'],
#  ['Muffin', 'Tea', 'Coffee'],
#  ['Coffee'],
#  ['Tea', 'Coffee'],
#  ['Hearty & Seasonal', 'Cake', 'Coffee'],
#  ['Tea', 'Bread', 'Cake'],
#  ['Coffee', 'Mighty Protein'],
#  ['Muffin', 'Hot chocolate'],
#  ['Soup', 'Mighty Protein', 'Coffee'],
#  ['Jam'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Cake', 'Hot chocolate'],
#  ['Muffin', 'Tea', 'Hot chocolate'],
#  ['Brownie'],
#  ['Cake', 'Coffee'],
#  ['Alfajores', 'Tea', 'Victorian Sponge'],
#  ['Bread'],
#  ['Tartine', 'Tea'],
#  ['Tea', 'Mighty Protein'],
#  ['Fudge', 'Bread'],
#  ['Medialuna', 'Tartine', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Alfajores', 'Tea', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Pastry'],
#  ['Alfajores'],
#  ['Alfajores', 'Hearty & Seasonal', 'Tea', 'Pastry'],
#  ['Sandwich', 'Tea'],
#  ['Empanadas', 'Tea'],
#  ['Alfajores', 'Tea'],
#  ['Alfajores'],
#  ['Pastry', 'Dulce de Leche'],
#  ['Pastry', 'Coffee'],
#  ['Farm House', 'Coffee'],
#  ['Medialuna', 'Bread', 'Scandinavian'],
#  ['Bread'],
#  ['Alfajores', 'Tea', 'Pastry'],
#  ['Pastry', 'Coffee'],
#  ['Farm House', 'Muffin', 'Bread', 'Pastry'],
#  ['Medialuna', 'Tea'],
#  ['Alfajores'],
#  ['Sandwich', 'Tea'],
#  ['Tea', 'Bread'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Alfajores', 'Empanadas', 'Muffin', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Tea', 'Bread', 'Pastry'],
#  ['Tea', 'Bread'],
#  ['Muffin'],
#  ['Muffin', 'Coffee'],
#  ['Medialuna', 'Bread', 'Pastry', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Muffin', 'Bread', 'Scandinavian', 'Hot chocolate'],
#  ['Farm House'],
#  ['Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Muffin'],
#  ['Tea', 'Keeping It Local', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Scandinavian'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Coke', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Scandinavian', 'Coffee', 'Muffin', 'Medialuna', 'Bread'],
#  ['Bread'],
#  ['Coke'],
#  ['Bread', 'Scandinavian'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Scandinavian'],
#  ['Fudge'],
#  ['Soup', 'Hearty & Seasonal', 'Coffee'],
#  ['Coke'],
#  ['Cookies', 'Tea', 'Coffee'],
#  ['Tea', 'Pastry', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Soup', 'Sandwich', 'Muffin', 'Coffee'],
#  ['Muffin', 'Tea', 'Coffee'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Empanadas', 'Bread', 'Scandinavian'],
#  ['Tartine', 'Coffee'],
#  ['Tea'],
#  ['Scandinavian'],
#  ['Muffin'],
#  ['Bread', 'Scandinavian'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cookies', 'Scandinavian'],
#  ['Medialuna', 'Empanadas', 'Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Tea', 'Pastry'],
#  ['Pastry', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Keeping It Local', 'Coffee'],
#  ['Fudge'],
#  ['Tartine', 'Coffee'],
#  ['Medialuna', 'Coffee', 'Pastry', 'Hot chocolate'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Coke'],
#  ['Alfajores', 'Coffee'],
#  ['Muffin'],
#  ['Fudge', 'Farm House', 'Brownie'],
#  ['Coffee'],
#  ['Farm House', 'Muffin', 'Tea'],
#  ['Pastry', 'Coffee'],
#  ['Brownie', 'Pastry'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Juice', 'Pastry', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Alfajores', 'Tea'],
#  ['Alfajores', 'Coffee'],
#  ['Scandinavian'],
#  ['Medialuna', 'Pastry'],
#  ['Brownie'],
#  ['Farm House'],
#  ['Cookies', 'Coffee'],
#  ['Soup'],
#  ['Brownie', 'Art Tray', 'Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Soup', 'Frittata', 'Art Tray', 'Alfajores'],
#  ['Sandwich', 'Coffee'],
#  ['Tea'],
#  ['Farm House'],
#  ['Muffin', 'Scandinavian'],
#  ['Farm House'],
#  ['Scandinavian'],
#  ['Soup'],
#  ['Hearty & Seasonal', 'Tea', 'Bread'],
#  ['Hot chocolate'],
#  ['Sandwich', 'Hearty & Seasonal', 'Coffee'],
#  ['Sandwich', 'Hearty & Seasonal', 'Brownie', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Soup', 'Brownie', 'Coffee'],
#  ['Alfajores', 'Sandwich', 'Focaccia'],
#  ['Tartine', 'Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Muffin', 'Tea', 'Hot chocolate'],
#  ['Pastry'],
#  ['Hearty & Seasonal', 'Brownie', 'Bowl Nic Pitt', 'Coffee', 'Soup'],
#  ['Coffee'],
#  ['Medialuna', 'Alfajores', 'Farm House', 'Scandinavian'],
#  ['Soup', 'Coffee'],
#  ['Tea'],
#  ['Cookies', 'Tea', 'Coffee'],
#  ['Muffin', 'Tea'],
#  ['Brownie', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Bread Pudding', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Hot chocolate'],
#  ['Hot chocolate', 'Farm House', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Hot chocolate', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Focaccia', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Bread', 'Keeping It Local'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Cookies', 'Tartine', 'Coffee'],
#  ['Tea', 'Bread'],
#  ['Coffee', 'Bread', 'Keeping It Local'],
#  ['Medialuna', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Tea'],
#  ['Soup', 'Coke', 'Juice'],
#  ['Bread'],
#  ['Brownie'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread', 'Pastry', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Cookies', 'Bread'],
#  ['Eggs', 'Fudge'],
#  ['Bread'],
#  ['Muffin', 'Bread'],
#  ['Soup'],
#  ['Bread Pudding', 'Coffee'],
#  ['Tartine', 'Bread'],
#  ['Coffee', 'Sandwich', 'Bread Pudding', 'Jam', 'Fudge'],
#  ['Soup', 'Bread Pudding', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Soup', 'Bread', 'Coffee'],
#  ['Soup', 'Tea', 'Focaccia'],
#  ['Cookies', 'My-5 Fruit Shoot', 'Coffee'],
#  ['Coffee'],
#  ['Sandwich', 'Tea', 'Coffee'],
#  ['Scandinavian'],
#  ['Adjustment'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Medialuna', 'Brownie'],
#  ['Brownie', 'Bread', 'Pastry'],
#  ['Cookies', 'Bread', 'Pastry'],
#  ['Bread'],
#  ['Cookies', 'Juice', 'Pastry', 'Coffee'],
#  ['Cookies', 'Pastry', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Cookies', 'Alfajores', 'Bread', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Keeping It Local', 'Coffee', 'Cookies', 'Jam', 'Tea', 'Bread'],
#  ['Juice', 'Pastry', 'Coffee'],
#  ['Medialuna', 'Bread', 'Focaccia'],
#  ['Medialuna', 'Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Coffee', 'Cookies', 'Truffles', 'Bread'],
#  ['Tea', 'Art Tray'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cookies', 'Coffee'],
#  ['Brownie'],
#  ['Tea', 'Empanadas', 'Bread'],
#  ['Bread', 'Hot chocolate'],
#  ['Cookies', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Sandwich', 'Tea', 'Bread'],
#  ['Soup', 'Sandwich', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Soup', 'Empanadas', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Hearty & Seasonal', 'Coffee', 'Soup', 'Juice', 'Smoothies'],
#  ['Scandinavian',
#   'Coffee',
#   'Cookies',
#   'Sandwich',
#   'Hot chocolate',
#   'Alfajores'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Bread'],
#  ['Cookies', 'Alfajores', 'Bread'],
#  ['Brownie', 'Tea'],
#  ['Tea', 'Bread'],
#  ['Alfajores', 'Coffee'],
#  ['Bread'],
#  ['Empanadas', 'Coffee'],
#  ['Bread'],
#  ['Hot chocolate', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Truffles', 'Brownie', 'Tea', 'Hot chocolate'],
#  ['Keeping It Local', 'Coffee'],
#  ['Coffee'],
#  ['Alfajores'],
#  ['Chimichurri Oil', 'Scandinavian'],
#  ['Truffles', 'Bread'],
#  ['Brownie', 'Focaccia'],
#  ['Bread', 'Coffee'],
#  ['Cookies', 'Tea', 'Art Tray', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Alfajores', 'Coke', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Medialuna', 'Bread', 'Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Bread', 'Keeping It Local'],
#  ['Bread'],
#  ['Scandinavian', 'Coffee'],
#  ['Medialuna', 'Farm House', 'Bread', 'Pastry'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Farm House', 'Bread'],
#  ['Bread'],
#  ['Bread', 'Keeping It Local'],
#  ...]

# %%
# TransactionEncoder transforms the data into the correct format. Pandas helps us to create the dataframe:

te = TransactionEncoder()
te_ary = te.fit(records).transform(records) #records in form of list of lists to load it in TransactionEncoder() 
df = pd.DataFrame(te_ary, columns=te.columns_)
display(df)
# Out:
#       Adjustment  Afternoon with the baker  Alfajores  Argentina Night  \
# 0          False                     False      False            False
# 1          False                     False      False            False
# 2          False                     False      False            False
# 3          False                     False      False            False
# 4          False                     False      False            False
# ...          ...                       ...        ...              ...
# 9526       False                     False      False            False
# 9527       False                     False      False            False
# 9528       False                     False      False            False
# 9529       False                     False      False            False
# 9530       False                     False      False            False
#
#       Art Tray  Bacon  Baguette  Bakewell  Bare Popcorn  Basket  ...  \
# 0        False  False     False     False         False   False  ...
# 1        False  False     False     False         False   False  ...
# 2        False  False     False     False         False   False  ...
# 3        False  False     False     False         False   False  ...
# 4        False  False     False     False         False   False  ...
# ...        ...    ...       ...       ...           ...     ...  ...
# 9526     False  False     False     False         False   False  ...
# 9527     False  False     False     False         False   False  ...
# 9528     False  False     False     False         False   False  ...
# 9529     False  False     False     False         False   False  ...
# 9530     False  False     False     False         False   False  ...
#
#       The BART  The Nomad  Tiffin  Toast  Truffles  Tshirt  Valentine's card  \
# 0        False      False   False  False     False   False             False
# 1        False      False   False  False     False   False             False
# 2        False      False   False  False     False   False             False
# 3        False      False   False  False     False   False             False
# 4        False      False   False  False     False   False             False
# ...        ...        ...     ...    ...       ...     ...               ...
# 9526     False      False   False  False     False   False             False
# 9527     False      False   False  False      True   False             False
# 9528     False      False   False  False     False   False             False
# 9529     False      False   False  False     False   False             False
# 9530     False      False   False  False     False   False             False
#
#       Vegan Feast  Vegan mincepie  Victorian Sponge
# 0           False           False             False
# 1           False           False             False
# 2           False           False             False
# 3           False           False             False
# 4           False           False             False
# ...           ...             ...               ...
# 9526        False           False             False
# 9527        False           False             False
# 9528        False           False             False
# 9529        False           False             False
# 9530        False           False             False
#
# [9531 rows x 95 columns]

# %%
# Let us return the items and itemsets with at least 50% support: By default, apriori returns the column indices of the items, which is helpful for association rule mining. Set use_colnames=True to convert these integer values into the respective item names:

from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
#As the there are frequent itemsets with min_support of 0.5, there's not output below.
display(frequent_itemsets)
#After changing value as low as 0.01, found frequent itemset and the maximum support for the dataset is 0.475 for {Coffee}
frequent_itemsets = apriori(df, min_support=0.0001, use_colnames=True)
display(frequent_itemsets)

# The association_rules() function allows to (1) specify your metric of interest (2) the according threshold. In this notebook, the implemented measures are confidence and lift. Let's say you are interested in rules derived from the frequent itemsets only if the level of confidence is above the 60 % threshold (min_threshold=0.6):
from mlxtend.frequent_patterns import association_rules
"""
For confidence metric with min thrshold of 0.6 there's only one association rule, {Toast}=>{Coffee}
On decreasing the min_threshold value to 0.1 for confidence metrics whoch has frequent itemset of min support of 0.01, gives some more 
association rules like {Spanish Brunch} => {Coffee} with confidence = 0.598837, slightly less than 0.6
Also, found the rules from same itemset have same support values.
"""
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
display(rules)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
display(rules)

# Q1. Display associations rules for metric = 'lift' and min_threshold = 1.2
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
print("Q1")
display(rules)
# Q2. Display associations rules for metric = 'support' and min_threshold = 0.6
rules = association_rules(frequent_itemsets, metric="support", min_threshold=0.05)
print("Q2")
display(rules)
# # Let us add a new feature to the dataframe showing the length of antecedents. Following code does this feature creation:
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
display(rules)
# Q3. At least 2 antecedents and confidence greater than or equal to 0.75
print("Q3")
"""
There are no rules with atleast 2 antecedent and confidence >= 0.75 even if the min support for frequent item set 
is reduced to 0.0001
"""
# frequent_itemsets = apriori(df, min_support=0.0001, use_colnames=True)
# # display(frequent_itemsets)
# display(rules[(rules['antecedent_len'] >=2) & (rules['confidence'] >= 0.75) ])

# frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)
# display(frequent_itemsets)
display(rules[(rules['antecedent_len'] >=1) & (rules['confidence'] >= 0.45) ])
# Q4. support atleast 0.8 and lift atleast 1.00
print("Q4")
"""
There are no rules with support>=0.8 and lift >= 1.00 even if the min support for frequent item set 
is 0.1
"""
display(rules[(rules['support'] >=0.8) & (rules['lift'] >= 1.00) ])
"""
reducing values to support>=0.05 and lift >= 0.005
"""
display(rules[(rules['support'] >=0.05) & (rules['lift'] >= 0.005) ])
# Q5. sort the rules in descending order first by length of antecedents and then by lift
print("Q5")
display(rules.sort_values(['antecedent_len', 'lift'], ascending =[False, False]))
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []
#         support                                           itemsets
# 0      0.000105                                       (Adjustment)
# 1      0.004512                         (Afternoon with the baker)
# 2      0.036093                                        (Alfajores)
# 3      0.000734                                  (Argentina Night)
# 4      0.003987                                         (Art Tray)
# ...         ...                                                ...
# 14496  0.000105  (Pastry, Coffee, Cookies, Juice, Tiffin, Tea, ...
# 14497  0.000105  (Pastry, Coffee, Cookies, Juice, Tiffin, Tea, ...
# 14498  0.000105  (Brownie, Bare Popcorn, Art Tray, Coffee, Cook...
# 14499  0.000105  (Chicken Stew, Duck egg, Brownie, Coffee, Cook...
# 14500  0.000105  (Granola, Coffee, Sandwich, Cake, Hot chocolat...
#
# [14501 rows x 2 columns]
#                                  antecedents  \
# 0                                    (Bacon)
# 1                                 (Art Tray)
# 2                           (Hack the stack)
# 3                                    (Bacon)
# 4                                    (Bacon)
# ...                                      ...
# 167382           (Medialuna, Bread, Granola)
# 167383              (Sandwich, Muffin, Cake)
# 167384  (Medialuna, Sandwich, Hot chocolate)
# 167385                     (Muffin, Granola)
# 167386                  (Medialuna, Granola)
#
#                                               consequents  antecedent support  \
# 0                                              (Art Tray)            0.000105
# 1                                                (Coffee)            0.003987
# 2                                              (Art Tray)            0.000210
# 3                                                (Coffee)            0.000105
# 4                                                 (Juice)            0.000105
# ...                                                   ...                 ...
# 167382  (Coffee, Sandwich, Cake, Hot chocolate, Muffin...            0.000105
# 167383  (Coffee, Granola, Hot chocolate, Tea, NONE, Me...            0.000105
# 167384  (Coffee, Granola, Cake, Muffin, Tea, NONE, Bread)            0.000105
# 167385  (Coffee, Sandwich, Cake, Hot chocolate, Tea, N...            0.000105
# 167386  (Coffee, Sandwich, Cake, Hot chocolate, Muffin...            0.000105
#
#         consequent support   support  confidence         lift  leverage  \
# 0                 0.003987  0.000105    1.000000   250.815789  0.000105
# 1                 0.475081  0.002728    0.684211     1.440197  0.000834
# 2                 0.003987  0.000210    1.000000   250.815789  0.000209
# 3                 0.475081  0.000105    1.000000     2.104903  0.000055
# 4                 0.038296  0.000105    1.000000    26.112329  0.000101
# ...                    ...       ...         ...          ...       ...
# 167382            0.000105  0.000105    1.000000  9531.000000  0.000105
# 167383            0.000105  0.000105    1.000000  9531.000000  0.000105
# 167384            0.000105  0.000105    1.000000  9531.000000  0.000105
# 167385            0.000105  0.000105    1.000000  9531.000000  0.000105
# 167386            0.000105  0.000105    1.000000  9531.000000  0.000105
#
#         conviction
# 0              inf
# 1         1.662243
# 2              inf
# 3              inf
# 4              inf
# ...            ...
# 167382         inf
# 167383         inf
# 167384         inf
# 167385         inf
# 167386         inf
#
# [167387 rows x 9 columns]
#                  antecedents  \
# 0          (Argentina Night)
# 1                (Alfajores)
# 2       (Brioche and salami)
# 3                (Alfajores)
# 4               (Chocolates)
# ...                      ...
# 266296     (Muffin, Granola)
# 266297        (Tea, Granola)
# 266298       (NONE, Granola)
# 266299  (Medialuna, Granola)
# 266300      (Bread, Granola)
#
#                                               consequents  antecedent support  \
# 0                              (Afternoon with the baker)            0.000734
# 1                                                 (Bread)            0.036093
# 2                                             (Alfajores)            0.000315
# 3                                                  (Cake)            0.036093
# 4                                             (Alfajores)            0.000944
# ...                                                   ...                 ...
# 266296  (Coffee, Sandwich, Cake, Hot chocolate, Tea, N...            0.000105
# 266297  (Coffee, Sandwich, Cake, Hot chocolate, Muffin...            0.000734
# 266298  (Coffee, Sandwich, Cake, Hot chocolate, Muffin...            0.000839
# 266299  (Coffee, Sandwich, Cake, Hot chocolate, Muffin...            0.000105
# 266300  (Coffee, Sandwich, Cake, Hot chocolate, Muffin...            0.000944
#
#         consequent support   support  confidence         lift  leverage  \
# 0                 0.004512  0.000210    0.285714    63.328904  0.000207
# 1                 0.324940  0.010282    0.284884     0.876728 -0.001446
# 2                 0.036093  0.000105    0.333333     9.235465  0.000094
# 3                 0.103137  0.004092    0.113372     1.099236  0.000369
# 4                 0.036093  0.000105    0.111111     3.078488  0.000071
# ...                    ...       ...         ...          ...       ...
# 266296            0.000105  0.000105    1.000000  9531.000000  0.000105
# 266297            0.000105  0.000105    0.142857  1361.571429  0.000105
# 266298            0.000105  0.000105    0.125000  1191.375000  0.000105
# 266299            0.000105  0.000105    1.000000  9531.000000  0.000105
# 266300            0.000105  0.000105    0.111111  1059.000000  0.000105
#
#         conviction
# 0         1.393684
# 1         0.943987
# 2         1.445861
# 3         1.011544
# 4         1.084396
# ...            ...
# 266296         inf
# 266297    1.166544
# 266298    1.142737
# 266299         inf
# 266300    1.124882
#
# [266301 rows x 9 columns]
# Q1
#                        antecedents  \
# 0                (Argentina Night)
# 1       (Afternoon with the baker)
# 2       (Afternoon with the baker)
# 3                       (Duck egg)
# 4       (Afternoon with the baker)
# ...                            ...
# 408669                    (Muffin)
# 408670                       (Tea)
# 408671                      (NONE)
# 408672                 (Medialuna)
# 408673                     (Bread)
#
#                                               consequents  antecedent support  \
# 0                              (Afternoon with the baker)            0.000734
# 1                                       (Argentina Night)            0.004512
# 2                                              (Duck egg)            0.004512
# 3                              (Afternoon with the baker)            0.001259
# 4                                  (Extra Salami or Feta)            0.004512
# ...                                                   ...                 ...
# 408669  (Granola, Coffee, Sandwich, Cake, Hot chocolat...            0.038191
# 408670  (Granola, Coffee, Sandwich, Cake, Hot chocolat...            0.141643
# 408671  (Granola, Coffee, Sandwich, Cake, Hot chocolat...            0.079005
# 408672  (Granola, Coffee, Sandwich, Cake, Hot chocolat...            0.061379
# 408673  (Granola, Coffee, Sandwich, Cake, Hot chocolat...            0.324940
#
#         consequent support   support  confidence       lift  leverage  \
# 0                 0.004512  0.000210    0.285714  63.328904  0.000207
# 1                 0.000734  0.000210    0.046512  63.328904  0.000207
# 2                 0.001259  0.000105    0.023256  18.470930  0.000099
# 3                 0.004512  0.000105    0.083333  18.470930  0.000099
# 4                 0.003987  0.000105    0.023256   5.832925  0.000087
# ...                    ...       ...         ...        ...       ...
# 408669            0.000105  0.000105    0.002747  26.184066  0.000101
# 408670            0.000105  0.000105    0.000741   7.060000  0.000090
# 408671            0.000105  0.000105    0.001328  12.657371  0.000097
# 408672            0.000105  0.000105    0.001709  16.292308  0.000098
# 408673            0.000105  0.000105    0.000323   3.077494  0.000071
#
#         conviction
# 0         1.393684
# 1         1.048010
# 2         1.022520
# 3         1.085987
# 4         1.019728
# ...            ...
# 408669    1.002650
# 408670    1.000636
# 408671    1.001225
# 408672    1.001607
# 408673    1.000218
#
# [408674 rows x 9 columns]
# Q2
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (Bread)    (Coffee)            0.324940            0.475081  0.089393
# 1    (Coffee)     (Bread)            0.475081            0.324940  0.089393
# 2      (Cake)    (Coffee)            0.103137            0.475081  0.054349
# 3    (Coffee)      (Cake)            0.475081            0.103137  0.054349
#
#    confidence      lift  leverage  conviction
# 0    0.275105  0.579069  -0.06498    0.724131
# 1    0.188163  0.579069  -0.06498    0.831522
# 2    0.526958  1.109196   0.00535    1.109667
# 3    0.114399  1.109196   0.00535    1.012717
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (Bread)    (Coffee)            0.324940            0.475081  0.089393
# 1    (Coffee)     (Bread)            0.475081            0.324940  0.089393
# 2      (Cake)    (Coffee)            0.103137            0.475081  0.054349
# 3    (Coffee)      (Cake)            0.475081            0.103137  0.054349
#
#    confidence      lift  leverage  conviction  antecedent_len
# 0    0.275105  0.579069  -0.06498    0.724131               1
# 1    0.188163  0.579069  -0.06498    0.831522               1
# 2    0.526958  1.109196   0.00535    1.109667               1
# 3    0.114399  1.109196   0.00535    1.012717               1
# Q3
#   antecedents consequents  antecedent support  consequent support   support  \
# 2      (Cake)    (Coffee)            0.103137            0.475081  0.054349
#
#    confidence      lift  leverage  conviction  antecedent_len
# 2    0.526958  1.109196   0.00535    1.109667               1
# Q4
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, antecedent_len]
# Index: []
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (Bread)    (Coffee)            0.324940            0.475081  0.089393
# 1    (Coffee)     (Bread)            0.475081            0.324940  0.089393
# 2      (Cake)    (Coffee)            0.103137            0.475081  0.054349
# 3    (Coffee)      (Cake)            0.475081            0.103137  0.054349
#
#    confidence      lift  leverage  conviction  antecedent_len
# 0    0.275105  0.579069  -0.06498    0.724131               1
# 1    0.188163  0.579069  -0.06498    0.831522               1
# 2    0.526958  1.109196   0.00535    1.109667               1
# 3    0.114399  1.109196   0.00535    1.012717               1
# Q5
#   antecedents consequents  antecedent support  consequent support   support  \
# 2      (Cake)    (Coffee)            0.103137            0.475081  0.054349
# 3    (Coffee)      (Cake)            0.475081            0.103137  0.054349
# 0     (Bread)    (Coffee)            0.324940            0.475081  0.089393
# 1    (Coffee)     (Bread)            0.475081            0.324940  0.089393
#
#    confidence      lift  leverage  conviction  antecedent_len
# 2    0.526958  1.109196   0.00535    1.109667               1
# 3    0.114399  1.109196   0.00535    1.012717               1
# 0    0.275105  0.579069  -0.06498    0.724131               1
# 1    0.188163  0.579069  -0.06498    0.831522               1
